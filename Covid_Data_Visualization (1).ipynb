# %%
import cufflinks as cf
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import plotly.express as px
import sklearn
style.use('ggplot')
import plotly
import  plotly.graph_objects as go
from plotly.offline import init_notebook_mode,plot,iplot
plt.rcParams['figure.figsize']=15,10
import plotly.offline as pyo
from plotly.offline import plot
import folium
pyo.init_notebook_mode(connected=True)
cf.go_offline()
d=pd.read_csv("/content/drive/My Drive/data covid/india.csv")
d
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
from matplotlib import style
d.style.background_gradient(cmap="Reds")
# Out:
# <style  type="text/css" >
#     #T_fb3e202a_7a6f_11ea_ab3f_0242ac1c0002row0_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fb3e202a_7a6f_11ea_ab3f_0242ac1c0002row0_col2 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_fb3e202a_7a6f_11ea_ab3f_0242ac1c0002row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fb3e202a_7a6f_11ea_ab3f_0242ac1c0002row0_col4 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_fb3e202a_7a6f_11ea_ab3f_0242ac1c0002row0_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_fb3e202a_7a6f_11ea_ab3f_0242ac1c0002row1_col0 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_fb3e202a_7a6f_11ea_ab3f_0242ac1c0002row1_col2 {
#             background-color:  #fff0e8;
#             color:  #000000;
# ...

# %%
d.plot(kind='bar',x='Name of State / UT',y='Total Confirmed cases (Indian National)')

# %%
plotly.io.renderers.default='colab'

# %%
d.iplot(kind='bar',x='Name of State / UT',y='Total Confirmed cases (Indian National)')
plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8b2d7022-0f13-4a29-a0d5-444a92a4a01b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8b2d7022-0f13-4a29-a0d5-444a92a4a01b")) {
#                     Plotly.newPlot(
#                         '8b2d7022-0f13-4a29-a0d5-444a92a4a01b',
# ...

# %%
##matplotlib visualization
import matplotlib.pyplot as plt
plt.bar(d['Name of State / UT'],d['Total Confirmed cases (Indian National)'])
# Out:
# <BarContainer object of 26 artists>

# %%
##plotly expreSS(bar)
px.bar(d,x='Name of State / UT',y='Total Confirmed cases (Indian National)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="571fc7fb-54d1-4a8e-bdbe-204aaa475fe6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("571fc7fb-54d1-4a8e-bdbe-204aaa475fe6")) {
#                     Plotly.newPlot(
#                         '571fc7fb-54d1-4a8e-bdbe-204aaa475fe6',
# ...

# %%
##pandaS Scatter
d.plot(kind='scatter',x='Name of State / UT',y='Total Confirmed cases (Indian National)')

# %%
##matplotlib scatter
plt.scatter(d['Name of State / UT'],d['Total Confirmed cases (Indian National)'])

# %%
##plotly scatter
plotly.io.renderers.default='colab'
d.iplot(kind='scatter',x='Name of State / UT',y='Total Confirmed cases (Indian National)',mode='markers+lines',title='graph',xTitle='state',yTitle='cases',colors='Blue',size=30)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6b8bc3a4-c229-4eed-ba47-0773c7b98527" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6b8bc3a4-c229-4eed-ba47-0773c7b98527")) {
#                     Plotly.newPlot(
#                         '6b8bc3a4-c229-4eed-ba47-0773c7b98527',
# ...

# %%
##plotlyexpress scatter
px.scatter(d,x='Name of State / UT',y='Total Confirmed cases (Indian National)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f60dfa6f-4381-49ea-ae0e-28ac5821227b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f60dfa6f-4381-49ea-ae0e-28ac5821227b")) {
#                     Plotly.newPlot(
#                         'f60dfa6f-4381-49ea-ae0e-28ac5821227b',
# ...

# %%
##map
data=pd.read_csv('/content/drive/My Drive/data covid/Indian.csv')
data
# Out:
#                       Name of State / UT   Latitude  Longitude  Unnamed: 3
# 0                   Andaman And Nicobar   11.667026  92.735983         NaN
# 1                         Andhra Pradesh  14.750429  78.570026         NaN
# 2                     Arunachal Pradesh   27.100399  93.616601         NaN
# 3                                 Assam   26.749981  94.216667         NaN
# 4                                 Bihar   25.785414  87.479973         NaN
# 5                            Chandigarh   30.719997  76.780006         NaN
# 6                          Chhattisgarh   22.090420  82.159987         NaN
# 7                Dadra And Nagar Haveli   20.266578  73.016618         NaN
# 8                                  Delhi  28.669993  77.230004         NaN
# 9                                   Goa   15.491997  73.818001         NaN
# 10                               Haryana  28.450006  77.019991         NaN
# ...

# %%
##merging the data frames
full=pd.merge(data,d,on='Name of State / UT')
full
# Out:
#    Name of State / UT   Latitude  ...  Cured  Death
# 0      Andhra Pradesh  14.750429  ...      1      0
# 1               Delhi  28.669993  ...      6      1
# 2             Haryana  28.450006  ...     11      0
# 3           Karnataka  12.570381  ...      3      2
# 4              Kerala   8.900373  ...     11      0
# 5         Maharashtra  19.250232  ...     15      4
# 6              Punjab  31.519974  ...      0      1
# 7           Rajasthan  26.449999  ...      3      0
# 8           Telengana  18.112400  ...      1      0
# 9          Tamil Nadu  12.920386  ...      1      1
# 10      Uttar Pradesh  27.599981  ...     11      0
# 11        Uttarakhand  30.320409  ...      0      0
#
# [12 rows x 9 columns]

# %%
map=folium.Map(location=[20,70],zoom_start=5,tiles='Stamenterrain')
for lat,lon,val,name in zip(full['Latitude'],full['Longitude'],full['Total Confirmed cases (Indian National)'],full['Name of State / UT']):
  folium.CircleMarker([lat,lon],radius=val*0.8,popup=('<strong>state</strong>:' +str(name).capitalize()+'<br>' '<strong>total indian cases</strong>:' +str(val)+'<br>'),color='red',fill_color='red',fill_opacity=0.3).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
india=pd.read_excel(r'/content/drive/My Drive/corona/per_day_cases.xlsx',parse_dates=True,sheet_name='India')
Italy=pd.read_excel(r'/content/drive/My Drive/corona/per_day_cases.xlsx',parse_dates=True,sheet_name='Italy')
Korea=pd.read_excel(r'/content/drive/My Drive/corona/per_day_cases.xlsx',parse_dates=True,sheet_name='Korea')
Wuhan=pd.read_excel(r'/content/drive/My Drive/corona/per_day_cases.xlsx',parse_dates=True,sheet_name='Wuhan')

# %%
india
# Out:
#          Date  Total Cases  New Cases  Days after surpassing 100 cases
# 0  2020-01-30            1          1                              NaN
# 1  2020-01-31            1          0                              NaN
# 2  2020-02-01            1          0                              NaN
# 3  2020-02-02            2          1                              NaN
# 4  2020-02-03            3          1                              NaN
# 5  2020-02-04            3          0                              NaN
# 6  2020-02-05            3          0                              NaN
# 7  2020-02-06            3          0                              NaN
# 8  2020-02-07            3          0                              NaN
# 9  2020-02-08            3          0                              NaN
# 10 2020-02-09            3          0                              NaN
# 11 2020-02-10            3          0                              NaN
# ...

# %%
Italy
# Out:
#          Date  Total Cases  New Cases  Days after surpassing 100 cases
# 0  2020-01-31            2          2                              NaN
# 1  2020-02-01            2          0                              NaN
# 2  2020-02-02            2          0                              NaN
# 3  2020-02-03            2          0                              NaN
# 4  2020-02-04            2          0                              NaN
# 5  2020-02-05            2          0                              NaN
# 6  2020-02-06            3          1                              NaN
# 7  2020-02-07            3          0                              NaN
# 8  2020-02-08            3          0                              NaN
# 9  2020-02-09            3          0                              NaN
# 10 2020-02-10            3          0                              NaN
# 11 2020-02-11            3          0                              NaN
# ...

# %%
Korea
# Out:
#          Date  Total Cases  New Cases  Days after surpassing 100 cases
# 0  2020-01-20            1          1                              NaN
# 1  2020-01-21            1          0                              NaN
# 2  2020-01-22            1          0                              NaN
# 3  2020-01-23            1          0                              NaN
# 4  2020-01-24            2          1                              NaN
# ..        ...          ...        ...                              ...
# 56 2020-03-16         8236         74                             25.0
# 57 2020-03-17         8320         84                             26.0
# 58 2020-03-18         8413         93                             27.0
# 59 2020-03-19         8565        152                             28.0
# 60 2020-03-20         8652         87                             29.0
#
# [61 rows x 4 columns]

# %%
Wuhan
# Out:
#          Date  Total Cases  New Cases
# 0  2020-01-22          444          0
# 1  2020-01-23          444          0
# 2  2020-01-24          549        105
# 3  2020-01-25          761        212
# 4  2020-01-26         1058        297
# 5  2020-01-27         1423        365
# 6  2020-01-28         3554       2131
# 7  2020-01-29         3554          0
# 8  2020-01-30         4903       1349
# 9  2020-01-31         5806        903
# 10 2020-01-02         7153       1347
# 11 2020-02-02        11177       4024
# 12 2020-02-03        13522       2345
# 13 2020-02-04        16678       3156
# 14 2020-02-05        19665       2987
# 15 2020-02-06        22112       2447
# 16 2020-02-07        24953       2841
# 17 2020-02-08        27100       2147
# 18 2020-02-09        29631       2531
# 19 2020-02-10        31728       2097
# 20 2020-02-11        33366       1638
# 21 2020-02-12        33366          0
# 22 2020-02-13        48206      14840
# 23 2020-02-14        54406       6200
# ...

# %%
##matplotlib
plt.bar(india['Date'],india['Total Cases'])
plotly.io.renderers.default='colab'
##plotly bar(e)
px.bar(india,x='Date',y='Total Cases',color='Total Cases')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c02436f9-673c-49a5-80a2-805098abf313" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c02436f9-673c-49a5-80a2-805098abf313")) {
#                     Plotly.newPlot(
#                         'c02436f9-673c-49a5-80a2-805098abf313',
# ...

# %%
##matplotlib
plt.bar(Italy['Date'],Italy['Total Cases'])
plotly.io.renderers.default='colab'
##plotly bar(e)
px.bar(Italy,x='Date',y='Total Cases',color='Total Cases')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6112fd56-877f-4a9a-a7ec-b382b88bbdb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6112fd56-877f-4a9a-a7ec-b382b88bbdb7")) {
#                     Plotly.newPlot(
#                         '6112fd56-877f-4a9a-a7ec-b382b88bbdb7',
# ...

# %%
##matplotlib
plt.bar(Korea['Date'],Korea['Total Cases'])
plotly.io.renderers.default='colab'
##plotly bar(e)
px.bar(Korea,x='Date',y='Total Cases',color='Total Cases')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1ae4bb07-9796-441a-a399-612bb53dfb8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ae4bb07-9796-441a-a399-612bb53dfb8e")) {
#                     Plotly.newPlot(
#                         '1ae4bb07-9796-441a-a399-612bb53dfb8e',
# ...

# %%
##matplotlib
plt.bar(Wuhan['Date'],Wuhan['Total Cases'])
plotly.io.renderers.default='colab'
##plotly bar(e)
px.bar(Wuhan,x='Date',y='Total Cases',color='Total Cases')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="100bb722-9eed-46bc-9422-0e2e59620c35" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("100bb722-9eed-46bc-9422-0e2e59620c35")) {
#                     Plotly.newPlot(
#                         '100bb722-9eed-46bc-9422-0e2e59620c35',
# ...

# %%
##matplotlib
plt.scatter(india['Date'],india['Total Cases'],marker='*')
plotly.io.renderers.default='colab'
##plotly bar(e)
px.scatter(india,x='Date',y='Total Cases',color='Total Cases')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8379fc84-b885-4fae-8f84-ab9f3f64c8ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8379fc84-b885-4fae-8f84-ab9f3f64c8ac")) {
#                     Plotly.newPlot(
#                         '8379fc84-b885-4fae-8f84-ab9f3f64c8ac',
# ...

# %%
plt.plot(india['Date'],india['Total Cases'])

# %%
##pandaS Scatter
india.iplot(kind='scatter',x='Date',y='Total Cases',mode='lines+markers')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="54c651c3-8968-41c5-a233-f47091a3240c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("54c651c3-8968-41c5-a233-f47091a3240c")) {
#                     Plotly.newPlot(
#                         '54c651c3-8968-41c5-a233-f47091a3240c',
# ...

# %%
#Subplots using Bar Graph

# %%
from plotly.subplots import make_subplots

fig=make_subplots(
    rows=2,cols=2,
    specs=[[{"secondary_y":True},{"secondary_y":True}],[{"secondary_y":True},{"secondary_y":True}]],
    subplot_titles=("S.Korea","Italy","India","Wuhan"))

fig.add_trace(go.Bar(x=Korea['Date'],y=Korea['Total Cases'],
                    marker=dict(color=Korea['Total Cases'],coloraxis="coloraxis")),1,1)

fig.add_trace(go.Bar(x=Italy['Date'],y=Italy['Total Cases'],
                    marker=dict(color=Italy['Total Cases'],coloraxis="coloraxis")),1,2)

fig.add_trace(go.Bar(x=india['Date'],y=india['Total Cases'],
                    marker=dict(color=india['Total Cases'],coloraxis="coloraxis")),2,1)

fig.add_trace(go.Bar(x=Wuhan['Date'],y=Wuhan['Total Cases'],
                    marker=dict(color=Wuhan['Total Cases'],coloraxis="coloraxis")),2,2)



fig.update_layout(coloraxis=dict(colorscale='Bluered_r'),showlegend=False,title_text="Total Cases in 4 Countries")

fig.update_layout(plot_bgcolor='rgb(230,230,230)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a837d4c3-3301-42b3-b1cc-a93a32f4ac3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a837d4c3-3301-42b3-b1cc-a93a32f4ac3c")) {
#                     Plotly.newPlot(
#                         'a837d4c3-3301-42b3-b1cc-a93a32f4ac3c',
# ...
